# %%
import sys
import os
from matplotlib import pyplot as plt
import numpy as np
import xarray as xr
import pandas as pd
from xgcm import Grid
import dask.array as da

import gigatl_lib as gl

# %matplotlib inline

# %%
def findLatLonIndex(ds, lonValue, latValue):
        ''' Find nearest  grid point of  click value '''
        a = abs(ds['xi_rho'] - lonValue) + \
            abs(ds['eta_rho'] - latValue)
        return np.unravel_index(a.argmin(), a.shape)

# %%
def findDepthIndex(z, depth):
        ''' Find nearest  grid point'''
        a = abs(z - depth)
        return xr.DataArray(a.argmin(dim='s_rho'))

# %%
from dask.distributed import Client, LocalCluster
#
# Initialisation d'un cluster de 32 coeurs
cluster = LocalCluster(processes=False, n_workers=1, threads_per_worker=10)
client = Client(cluster)
client
# Out:
# /home1/dunree/slgentil/.miniconda3/envs/croco/lib/python3.7/site-packages/distributed/dashboard/core.py:72: UserWarning:
# Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the diagnostics dashboard on a random port instead.
#   warnings.warn("\n" + msg)
# <Client: 'inproc://134.246.146.72/6760/1' processes=1 threads=10, memory=67.17 GB>

# %%
# On récupère la liste des fichiers à ouvrir via le fichier liste 
path = "/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/"
#filenames = path + pd.read_csv('liste.122014',header=None)
filenames = path + pd.read_csv('liste.2014',header=None)
filenames = filenames.values.flatten().tolist()
filenames
# Out:
# ['/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-01-02-2014-01-06.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-01-07-2014-01-11.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-01-12-2014-01-16.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-01-17-2014-01-21.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-01-22-2014-01-26.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-01-27-2014-01-31.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-02-01-2014-02-05.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-02-06-2014-02-10.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-02-11-2014-02-15.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-02-16-2014-02-20.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-02-21-2014-02-25.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-02-26-2014-03-02.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-03-03-2014-03-07.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-03-08-2014-03-12.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-03-13-2014-03-17.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-03-18-2014-03-22.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-03-23-2014-03-27.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-03-28-2014-04-01.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-04-02-2014-04-06.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-04-07-2014-04-11.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-04-12-2014-04-16.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-04-17-2014-04-21.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-04-22-2014-04-26.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-04-27-2014-05-01.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-05-02-2014-05-06.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-05-07-2014-05-11.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-05-12-2014-05-16.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-05-17-2014-05-21.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-05-22-2014-05-26.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-05-27-2014-05-31.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-06-01-2014-06-05.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-06-06-2014-06-10.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-06-11-2014-06-15.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-06-16-2014-06-20.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-06-21-2014-06-25.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-06-26-2014-06-30.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-07-01-2014-07-05.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-07-06-2014-07-10.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-07-11-2014-07-15.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-07-16-2014-07-20.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-07-21-2014-07-25.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-07-26-2014-07-30.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-07-31-2014-08-04.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-08-05-2014-08-09.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-08-10-2014-08-14.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-08-15-2014-08-19.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-08-20-2014-08-24.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-08-25-2014-08-29.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-08-30-2014-09-03.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-09-04-2014-09-08.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-09-09-2014-09-13.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-09-14-2014-09-18.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-09-19-2014-09-23.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-09-24-2014-09-28.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-09-29-2014-10-03.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-10-04-2014-10-08.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-10-09-2014-10-13.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-10-14-2014-10-18.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-10-19-2014-10-23.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-10-24-2014-10-28.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-10-29-2014-11-02.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-11-03-2014-11-07.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-11-08-2014-11-12.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-11-13-2014-11-17.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-11-18-2014-11-22.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-11-23-2014-11-27.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-11-28-2014-12-02.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-12-03-2014-12-07.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-12-08-2014-12-12.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-12-13-2014-12-17.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-12-18-2014-12-22.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-12-23-2014-12-27.nc',
#  '/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/GIGATL6_12h_inst_2014-12-28-2015-01-01.nc']

# %%
datasets = []
for f in filenames:
    ds = xr.open_dataset(f, chunks={'time_counter': 1, 's_rho': 1},
                         drop_variables=['ubar', 'vbar', 'sustr', 'svstr','w',
                                         'temp','salt', 'hc','theta_s','theta_b',
                                         'Tcline','Vtransform','pm','pn','h','f','angle',
                                         'mask_rho','Cs_r','sc_r','Cs_w','sc_w','lon_rho',
                                         'lat_rho','lon_u','lat_u','lon_v','lat_v'])
    datasets.append(ds)
ds = xr.concat(datasets, dim='time_counter', coords='minimal', compat='override')

# %%
# On ajoute dans le dataset les paramètres de grille qui sont dans le 1ier fichier
path = "/home/datawork-lops-megatl/GIGATL6/GIGATL6_1h/HIS/"
gridname = path+'GIGATL6_12h_inst_2004-01-15-2004-01-19.nc'
gd = xr.open_dataset(gridname, chunks={'s_rho': 1})
ds['hc'] = gd.hc
ds['h'] = gd.h
ds['Vtransform'] = gd.Vtransform
ds['sc_r'] = gd.sc_r
ds['sc_w'] = gd.sc_w
ds['Cs_r'] = gd.Cs_r
ds['Cs_w'] = gd.Cs_w
ds['angle'] = gd.angle
ds['mask_rho'] = gd.mask_rho

# %%
# On modifie des dimensions et des coordonnées, on crée la grille xgcm
ds = gl.adjust_grid(ds)
L = ds.dims['x_rho']
M = ds.dims['y_rho']
N = ds.dims['s_rho']

# %%
# On crée la grille xgcm
ds = gl.xgcm_grid(ds)
grid = ds.attrs['xgcm-Grid']

# %%
# compute time step for temporal animation
# writing step in input files : 12h
dt = ( 12.* 3600.)
# keep one step per day
#step = int(86400. / dt)
step = int(10*86400. / dt)
ds2 = ds.isel(time_counter=slice(0,None,step))
ds2
# Out:
# <xarray.Dataset>
# Dimensions:              (axis_nbounds: 2, s_rho: 50, s_w: 51, time_counter: 37, x_rho: 1502, x_u: 1501, y_rho: 2002, y_v: 2001)
# Coordinates:
#     eta_rho              (y_rho, x_rho) float32 dask.array<chunksize=(2002, 1502), meta=np.ndarray>
#     xi_w                 (y_rho, x_rho) float32 dask.array<chunksize=(2002, 1502), meta=np.ndarray>
#     xi_rho               (y_rho, x_rho) float32 dask.array<chunksize=(2002, 1502), meta=np.ndarray>
#     eta_u                (y_rho, x_u) float32 dask.array<chunksize=(2002, 1501), meta=np.ndarray>
#     xi_u                 (y_rho, x_u) float32 dask.array<chunksize=(2002, 1501), meta=np.ndarray>
#     eta_v                (y_v, x_rho) float32 dask.array<chunksize=(2001, 1502), meta=np.ndarray>
#     eta_w                (y_rho, x_rho) float32 dask.array<chunksize=(2002, 1502), meta=np.ndarray>
#     xi_v                 (y_v, x_rho) float32 dask.array<chunksize=(2001, 1502), meta=np.ndarray>
#   * s_w                  (s_w) float32 -1.0 -0.98 -0.96 ... -0.04 -0.02 0.0
#   * s_rho                (s_rho) float32 -0.99 -0.97 -0.95 ... -0.05 -0.03 -0.01
#     time_instant         (time_counter) datetime64[ns] dask.array<chunksize=(1,), meta=np.ndarray>
#   * time_counter         (time_counter) datetime64[ns] 2014-01-02T12:00:00 ... 2014-12-28T12:00:00
# Dimensions without coordinates: axis_nbounds, x_rho, x_u, y_rho, y_v
# Data variables:
#     time_instant_bounds  (time_counter, axis_nbounds) datetime64[ns] dask.array<chunksize=(1, 2), meta=np.ndarray>
#     time_counter_bounds  (time_counter, axis_nbounds) datetime64[ns] dask.array<chunksize=(1, 2), meta=np.ndarray>
#     time                 (time_counter) float32 dask.array<chunksize=(1,), meta=np.ndarray>
#     zeta                 (time_counter, y_rho, x_rho) float32 dask.array<chunksize=(1, 2002, 1502), meta=np.ndarray>
#     u                    (time_counter, s_rho, y_rho, x_u) float32 dask.array<chunksize=(1, 1, 2002, 1501), meta=np.ndarray>
#     v                    (time_counter, s_rho, y_v, x_rho) float32 dask.array<chunksize=(1, 1, 2001, 1502), meta=np.ndarray>
#     rho                  (time_counter, s_rho, y_rho, x_rho) float32 dask.array<chunksize=(1, 1, 2002, 1502), meta=np.ndarray>
#     bvf                  (time_counter, s_w, y_rho, x_rho) float32 dask.array<chunksize=(1, 51, 2002, 1502), meta=np.ndarray>
#     hc                   float32 ...
#     h                    (y_rho, x_rho) float32 dask.array<chunksize=(2002, 1502), meta=np.ndarray>
#     Vtransform           float32 ...
#     sc_r                 (s_rho) float32 dask.array<chunksize=(1,), meta=np.ndarray>
#     sc_w                 (s_w) float32 dask.array<chunksize=(51,), meta=np.ndarray>
#     Cs_r                 (s_rho) float32 dask.array<chunksize=(1,), meta=np.ndarray>
#     Cs_w                 (s_w) float32 dask.array<chunksize=(51,), meta=np.ndarray>
#     angle                (y_rho, x_rho) float32 dask.array<chunksize=(2002, 1502), meta=np.ndarray>
#     mask_rho             (y_rho, x_rho) float32 dask.array<chunksize=(2002, 1502), meta=np.ndarray>
# Attributes:
#     name:           ./HIS/GIGATL6_12h_inst
#     description:    Created by xios
#     Conventions:    CF-1.6
#     timeStamp:      2019-Dec-04 21:14:13 GMT
#     uuid:           e34ba682-ad00-4ff2-b3ec-2efc4bc62095
#     title:          GIGATL6
#     rst_file:       RST/gigatl6_rst_r13.120.nc
#     grd_file:       ./INIT/gigatl6_grd.120.nc
#     ini_file:       RST/gigatl6_rst_r12.120.nc
#     frc_file:       ./INIT/gigatl6_frc_clim.120.nc
#     VertCoordType:  NEW
#     theta_s:        5.0
#     theta_s_expl:   S-coordinate surface control parameter
#     theta_b:        2.0
#     theta_b_expl:   S-coordinate bottom control parameter
#     Tcline:         300.0
#     Tcline_expl:    S-coordinate surface/bottom layer width
#     Tcline_units:   meter
#     hc:             300.0
#     hc_expl:        S-coordinate parameter, critical depth
#     hc_units:       meter
#     sc_w:           have a look at variable sc_w in this file
#     Cs_w:           have a look at variable Cs_w in this file
#     sc_r:           have a look at variable sc_r in this file
#     Cs_r:           have a look at variable Cs_r in this file
#     ntimes:         2360880
#     ndtfast:        50
#     dt:             200.0
#     dtfast:         4.0
#     nwrt:           1728
#     tnu4_expl:      biharmonic mixing coefficient for tracers
#     units:          meter4 second-1
#     rdrg:           0.0
#     rdrg_expl:      linear drag coefficient
#     rdrg_units:     meter second-1
#     rho0:           1027.4
#     rho0_expl:      Mean density used in Boussinesq approximation
#     rho0_units:     kilogram meter-3
#     gamma2:         1.0
#     gamma2_expl:    Slipperiness parameter
#     x_sponge:       0.0
#     v_sponge:       0.0
#     sponge_expl:    Sponge parameters : extent (m) & viscosity (m2.s-1)
#     SRCS:           main.F step.F read_inp.F timers_roms.F init_scalars.F ini...
#     CPP-options:    REGIONAL GIGATL6 MPI_TIME MPI XIOS XIOS2 OBC_EAST OBC_NOR...
#     xgcm-Grid:      <xgcm.Grid>\nxi Axis (periodic):\n  * center   x_rho --> ...

# %%
# Find index of given longitude/latitude
lonValue = -30.
latValue = 0.
latindex, lonindex = findLatLonIndex(ds2, lonValue, latValue)
print(latindex, lonindex)
print(ds2.xi_rho.values[838,768],ds2.eta_rho.values[838,768])
# Out:
# 838 768
# -30.004793 -0.005113315

# %%
# extract u and interpolate at rho point
u = ds2.u.isel(x_u=slice(lonindex,lonindex+2),y_rho=latindex)
u = grid.interp(u,'xi',boundary=None).isel(x_rho=1)
print(u)
# Out:
# <xarray.DataArray 'mul-cbe2540312906321071171caa9a967f5' (time_counter: 37, s_rho: 50)>
# dask.array<getitem, shape=(37, 50), dtype=float32, chunksize=(1, 1), chunktype=numpy.ndarray>
# Coordinates:
#   * time_counter  (time_counter) datetime64[ns] 2014-01-02T12:00:00 ... 2014-12-28T12:00:00
#   * s_rho         (s_rho) float32 -0.99 -0.97 -0.95 -0.93 ... -0.05 -0.03 -0.01

# %%
# extract v and interpolate at rho point
v = ds2.v.isel(y_v=slice(latindex,latindex+2),x_rho=lonindex)
v = grid.interp(v,'eta',boundary=None).isel(y_rho=1)
print(v)
# Out:
# <xarray.DataArray 'mul-475942310daaab77390963a882f7b81b' (time_counter: 37, s_rho: 50)>
# dask.array<getitem, shape=(37, 50), dtype=float32, chunksize=(1, 1), chunktype=numpy.ndarray>
# Coordinates:
#   * time_counter  (time_counter) datetime64[ns] 2014-01-02T12:00:00 ... 2014-12-28T12:00:00
#   * s_rho         (s_rho) float32 -0.99 -0.97 -0.95 -0.93 ... -0.05 -0.03 -0.01

# %%
# extract angle
angle = ds2.angle.isel(x_rho=lonindex, y_rho=latindex)

# %%
# Compute vrot
vrot = u*np.sin(angle) + v*np.cos(angle)
vrot
# Out:
# <xarray.DataArray (time_counter: 37, s_rho: 50)>
# dask.array<add, shape=(37, 50), dtype=float32, chunksize=(1, 1), chunktype=numpy.ndarray>
# Coordinates:
#   * time_counter  (time_counter) datetime64[ns] 2014-01-02T12:00:00 ... 2014-12-28T12:00:00
#   * s_rho         (s_rho) float32 -0.99 -0.97 -0.95 -0.93 ... -0.05 -0.03 -0.01

# %%
# Compute depth at rho point
z_r = gl.get_z(ds2,zeta=ds2['zeta'],hgrid='r').isel(x_rho=lonindex, y_rho=latindex).persist()
z_r
# Out:
# /home1/dunree/slgentil/.miniconda3/envs/croco/lib/python3.7/site-packages/dask/array/core.py:3851: PerformanceWarning: Increasing number of chunks by factor of 37
#   **blockwise_kwargs
# /home1/dunree/slgentil/models/croco/gigatl/gigatl_lib.py:152: FutureWarning: This DataArray contains multi-dimensional coordinates. In the future, these coordinates will be transposed as well unless you specify transpose_coords=False.
#   z = z.transpose(*('time_counter',zdim,ydim,xdim))
# <xarray.DataArray 'z_r' (time_counter: 37, s_rho: 50)>
# dask.array<getitem, shape=(37, 50), dtype=float64, chunksize=(1, 1), chunktype=numpy.ndarray>
# Coordinates:
#     eta_rho       float32 -0.005113315
#     xi_w          float32 -30.004793
#     xi_rho        float32 -30.004793
#     eta_w         float32 -0.005113315
#     time_instant  (time_counter) datetime64[ns] 2014-01-02T12:00:00 ... 2014-12-28T12:00:00
#   * time_counter  (time_counter) datetime64[ns] 2014-01-02T12:00:00 ... 2014-12-28T12:00:00
#   * s_rho         (s_rho) float32 -0.99 -0.97 -0.95 -0.93 ... -0.05 -0.03 -0.01

# %%
# Compute Indices of nearest depth (not interpolated depth)
depth = -1000.
zIndex = findDepthIndex(z_r,depth)
zIndex
# Out:
# <xarray.DataArray 'z_r' (time_counter: 37)>
# array([21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21,
#        21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21, 21,
#        21, 21, 21])
# Coordinates:
#     eta_rho       float32 -0.005113315
#     xi_w          float32 -30.004793
#     xi_rho        float32 -30.004793
#     eta_w         float32 -0.005113315
#     time_instant  (time_counter) datetime64[ns] 2014-01-02T12:00:00 ... 2014-12-28T12:00:00
#   * time_counter  (time_counter) datetime64[ns] 2014-01-02T12:00:00 ... 2014-12-28T12:00:00

# %%
vrot.coords['z'] = z_r
vrot.coords['time'] = vrot.time_counter.expand_dims({'s_rho': N},axis=1)
vrot
# Out:
# <xarray.DataArray (time_counter: 37, s_rho: 50)>
# dask.array<add, shape=(37, 50), dtype=float32, chunksize=(1, 1), chunktype=numpy.ndarray>
# Coordinates:
#   * time_counter  (time_counter) datetime64[ns] 2014-01-02T12:00:00 ... 2014-12-28T12:00:00
#   * s_rho         (s_rho) float32 -0.99 -0.97 -0.95 -0.93 ... -0.05 -0.03 -0.01
#     eta_rho       float32 -0.005113315
#     xi_w          float32 -30.004793
#     xi_rho        float32 -30.004793
#     eta_w         float32 -0.005113315
#     time_instant  (time_counter) datetime64[ns] 2014-01-02T12:00:00 ... 2014-12-28T12:00:00
#     z             (time_counter, s_rho) float64 dask.array<chunksize=(1, 1), meta=np.ndarray>
#     time          (time_counter, s_rho) datetime64[ns] 2014-01-02T12:00:00 ... 2014-12-28T12:00:00

# %%
# %%time
#plot v at lon,lat,depth  in time
vrot[:,zIndex].plot()
# Out:
# CPU times: user 2.17 s, sys: 268 ms, total: 2.44 s
# Wall time: 6.03 s

# %%
# Plot v(z) at lon/lat in time
vrot.plot(x='time',y='z',vmin=-0.5, vmax=0.5, cmap = 'RdBu_r')
#vrot.plot()

# %%
ds2 = ds.isel(time_counter=0)
z = gl.get_z(ds2,zeta=ds2['zeta'])
vnew = gl.slice(ds2,ds2.rho,z,latitude=0.)
vnew.plot(x=[s for s in vnew.coords if "xi_" in s][0],
          y=[s for s in vnew.coords if "z" in s][0],
          vmin=-1., vmax=1., cmap = 'RdBu_r')
# Out:
# /home1/dunree/slgentil/models/croco/gigatl/gigatl_lib.py:155: FutureWarning: This DataArray contains multi-dimensional coordinates. In the future, these coordinates will be transposed as well unless you specify transpose_coords=False.
#   z = z.transpose(*(zdim,)+_zeta.dims)

# %%
rho = ds2.rho.isel(y_rho=800)
print(rho)
#rho.plot(x='xi_rho',y="s_rho",vmin=-1., vmax=1., cmap = 'RdBu_r')
ds2.eta_rho.plot()
# Out:
# <xarray.DataArray 'rho' (s_rho: 50, x_rho: 1502)>
# dask.array<getitem, shape=(50, 1502), dtype=float32, chunksize=(1, 1502), chunktype=numpy.ndarray>
# Coordinates:
#     eta_rho       (x_rho) float32 dask.array<chunksize=(1502,), meta=np.ndarray>
#     xi_w          (x_rho) float32 dask.array<chunksize=(1502,), meta=np.ndarray>
#     xi_rho        (x_rho) float32 dask.array<chunksize=(1502,), meta=np.ndarray>
#     eta_w         (x_rho) float32 dask.array<chunksize=(1502,), meta=np.ndarray>
#   * s_rho         (s_rho) float32 -0.99 -0.97 -0.95 -0.93 ... -0.05 -0.03 -0.01
#     time_instant  datetime64[ns] dask.array<chunksize=(), meta=np.ndarray>
#     time_counter  datetime64[ns] 2014-01-02T12:00:00
# Dimensions without coordinates: x_rho
# Attributes:
#     long_name:           density anomaly
#     units:               kilogram meter-3
#     online_operation:    instant
#     interval_operation:  12 h
#     interval_write:      12 h
#     cell_methods:        time: point
